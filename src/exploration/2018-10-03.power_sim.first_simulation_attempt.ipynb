# %% [markdown]
# This notebook is going to mostly scratch work looking at the "sample size" simulation.
#
# Specifically, I'll start with a case-control dataset (to simulate a "real" microbiome effect) and:
#
# - subsample cases and controls at different total N's
# - also subsample with different proportions of cases/controls
# - calculate significant associations
#     - need to remove OTUs which are completely zero before doing this
#     - and then correct for multiple tests
# - and see what percent of the "real" associations it recovers ("real" associations calculated from the whole dataset)
#
# In this exploration, I also need to make sure that the bugs which are significant in the smaller subset are the same ones as in the whole thing...

# %%
import pandas as pd
import numpy as np
import feather

from scipy.stats.mstats import kruskalwallis
from scipy.stats import ranksums, mannwhitneyu
# FDR correction
from statsmodels.sandbox.stats.multicomp import multipletests

# %%
# Taken from util.py in microbiomeHD
def univariate_one_col(xvals, yvals, pfun):
    try:
        h, p = pfun(xvals, yvals)
    except ValueError:
        p = 1
        h = 0
    return pd.Series([p, h])

def compare_otus_teststat(df, Xsmpls, Ysmpls, method='kruskal-wallis', multi_comp=None):
    """
    Compares columns between Xsmpls and Ysmpls, with statistical method=method.
    Returns dataframe with both the qvals ('p') and test statistic ('test-stat')

    parameters
    ----------
    df             dataframe, samples are in rows and OTUs in columns
    X,Ysmpls       list of samples to compare
    method         statistical method to use for comparison
    multi_comp     str, type of multiple comparison test to do.
                   Currently accepts 'fdr' or None

    outputs
    -------
    results        dataframe with OTUs in rows and 'p' and 'test-stat' in columns

    """
    if method == 'kruskal-wallis':
        pfun = kruskalwallis
    elif method == 'wilcoxon' or method == 'ranksums':
        pfun = ranksums
    elif method == 'mann-whitney':
        pfun = mannwhitneyu
        # Note: prob wanna add some kwargs here to say whether 2sided or not

    results = df.apply(
        lambda col: univariate_one_col(col.loc[Xsmpls].values, col.loc[Ysmpls].values, pfun)).T
    results.columns = ['p', 'test_stat']

    if multi_comp == 'fdr':
        _, results['q'], _, _ = multipletests(results['p'], method='fdr_bh')

    return results

def read_dataframe(fn):
    df = feather.read_dataframe(fn)
    df.index = df.iloc[:,0]
    df = df.iloc[:, 1:]
    
    return df

# %% [markdown]
# # The setup
#
# The eventual plots will be faceted by FMT response rate, x-axis = total N, y-axis = % of max rejections, and each line will be a study.
#
# So I'll need to make a dataframe with the following columns:
# - % cases (i.e. FMT response rate)
# - total N (x axis)
# - number reject (y axis)
# - total reject (for that study)
# - study (hue)
#
# ## CRC Baxter
#
# Let's start with one dataset, CRC Baxter.

# %%
fotu = '../../data/clean/crc_baxter.otu_table.feather'
fgenus = '../../data/clean/crc_baxter.otu_table.genus.feather'
fmeta = '../../data/clean/crc_baxter.metadata.feather'

df, genusdf, meta = (read_dataframe(f) for f in [fotu, fgenus, fmeta])
df.shape, genusdf.shape, meta.shape
# Out:
# ((490, 18448), (490, 163), (490, 72))

# %%
df.head()
# Out:
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Peptostreptococcaceae;g__Clostridium_XI;s__;d__denovo15989  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__;d__denovo15988  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo723  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Faecalibacterium;s__;d__denovo722  \
# index
# 2045653                                           0.000000
# 2087650                                           0.000717
# 2963670                                           0.000060
# 2527670                                           0.000000
# 3453650                                           0.000052
#
#          k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Prevotella;s__;d__denovo12511  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Blautia;s__;d__denovo12510  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__;s__;d__denovo12516  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo20538  \
# index
# 2045653                                            0.00000
# 2087650                                            0.00000
# 2963670                                            0.00006
# 2527670                                            0.00000
# 3453650                                            0.00000
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__;g__;s__;d__denovo20532  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Ruminococcus;s__;d__denovo20533  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#                                                                ...                                                         \
# index                                                          ...
# 2045653                                                        ...
# 2087650                                                        ...
# 2963670                                                        ...
# 2527670                                                        ...
# 3453650                                                        ...
#
#          k__Bacteria;p__Verrucomicrobia;c__Verrucomicrobiae;o__Verrucomicrobiales;f__Verrucomicrobiaceae;g__Akkermansia;s__;d__denovo14612  \
# index
# 2045653                                           0.000000
# 2087650                                           0.000000
# 2963670                                           0.000000
# 2527670                                           0.000000
# 3453650                                           0.000078
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Lachnospiracea_incertae_sedis;s__;d__denovo20807  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Coriobacteriales;f__Coriobacteriaceae;g__Enterorhabdus;s__;d__denovo19190  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Negativicutes;o__Selenomonadales;f__Acidaminococcaceae;g__Phascolarctobacterium;s__;d__denovo19192  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__;s__;d__denovo19193  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Verrucomicrobia;c__Verrucomicrobiae;o__Verrucomicrobiales;f__Verrucomicrobiaceae;g__Akkermansia;s__;d__denovo19195  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Dorea;s__;d__denovo19196  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo19197  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Bifidobacteriales;f__Bifidobacteriaceae;g__Bifidobacterium;s__;d__denovo19198  \
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
#          k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__;d__denovo20801
# index
# 2045653                                                0.0
# 2087650                                                0.0
# 2963670                                                0.0
# 2527670                                                0.0
# 3453650                                                0.0
#
# [5 rows x 18448 columns]

# %%
meta.groupby(['DiseaseState']).size()
# Out:
# DiseaseState
# CRC       120
# H         172
# nonCRC    198
# dtype: int64

# %% [markdown]
# Let's do CRC vs. H

# %%
h = meta.query('DiseaseState == "H"').index.tolist()
crc = meta.query('DiseaseState == "CRC"').index.tolist()

p = compare_otus_teststat(df, h, crc, method='kruskal-wallis', multi_comp='fdr')

# %%
p.sort_values(by='q').head(10)
# Out:
#                                                                p  test_stat  \
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  4.200885e-10  39.017198
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  2.873360e-08  30.791213
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  7.757245e-08  28.865752
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  1.368985e-07  27.766179
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  1.685480e-07  27.363906
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...  8.122350e-07  24.328614
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  3.289453e-06  21.639854
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  2.371054e-05  17.865299
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  2.769373e-05  17.569900
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  1.204994e-04  14.784855
#
#                                                            q
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000008
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000265
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000477
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000622
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000622
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...  0.002497
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.008669
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.054677
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.056766
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.178292

# %%
alpha = 0.05
sum(p['q'] <= alpha)
# Out:
# 7

# %% [markdown]
# ### Check genus-level full results

# %%
pgenus = compare_otus_teststat(genusdf, h, crc, method='kruskal-wallis', multi_comp='fdr')

# %%
pgenus.sort_values(by='q').head(10)
# Out:
#                                                                p  test_stat  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.042793e-10  38.307565
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  3.289881e-10  39.494480
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  1.174227e-09  37.011697
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  3.155495e-07  26.152126
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  1.197008e-05  19.168040
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  9.431220e-04  10.936027
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...  1.015943e-03  10.798283
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  8.253342e-04  11.183377
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...  1.305592e-03  10.334604
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  1.798781e-03   9.744316
#
#                                                                q
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  4.924876e-08
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  4.924876e-08
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  6.379968e-08
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  1.285864e-05
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  3.902247e-04
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  2.069983e-02
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...  2.069983e-02
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  2.069983e-02
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...  2.364571e-02
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  2.932013e-02

# %%
sum(pgenus['q'] <= 0.05)
# Out:
# 16

# %% [markdown]
# ## Subsample evenly
#
# Let's just try it once to check that the same bugs come out as significant. We'll subsample cases and controls to a significant portion of the original size just to make sure we still get hits.

# %%
# Set random seed
random_state = 12345
np.random.seed(random_state)

# %%
subh = np.random.choice(h, size=int(np.ceil(0.6*len(h))))
subcrc = np.random.choice(crc, size=int(np.ceil(0.6*len(crc))))

# %%
subp = compare_otus_teststat(df, subh, subcrc, method='kruskal-wallis', multi_comp='fdr')

# %%
subp.sort_values(by='q').head(10)
# Out:
#                                                            p  test_stat  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  0.000003  21.897024
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000002  22.924502
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000005  21.032451
# k__Bacteria;p__Proteobacteria;c__Deltaproteobac...  0.000009  19.632208
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000017  18.516770
# k__Bacteria;p__Proteobacteria;c__Alphaproteobac...  0.000040  16.871077
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000095  15.223713
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000225  13.610715
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000062  16.054263
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.000225  13.610817
#
#                                                            q
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  0.026536
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.026536
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.027769
# k__Bacteria;p__Proteobacteria;c__Deltaproteobac...  0.043294
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.062139
# k__Bacteria;p__Proteobacteria;c__Alphaproteobac...  0.123007
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.155675
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.155675
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.155675
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.155675

# %% [markdown]
# Let's also check genus-level results.

# %%
subpgenus = compare_otus_teststat(genusdf, subh, subcrc, method='kruskal-wallis', multi_comp='fdr')

# %%
subpgenus.sort_values(by='q').head(10)
# Out:
#                                                            p  test_stat  \
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000001  23.819784
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  0.000003  21.897024
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000189  13.942037
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.000235  13.526540
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000232  13.548569
# k__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.000290  13.135020
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000816  11.203638
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...  0.000904  11.015114
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.001150  10.568925
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.001864   9.678772
#
#                                                            q
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.000172
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  0.000234
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.007668
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.007668
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.007668
# k__Archaea;p__Euryarchaeota;c__Methanobacteria;...  0.007874
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.018413
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...  0.018413
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.020829
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.030385

# %% [markdown]
# I think this looks fine. Let's do both OTU- and genus-level moving forward (bc why not! Genus-level takes less time and is easier to compare with my meta-analysis, but OTU-level is probably more related to what clinicians do in real life)

# %% [markdown]
# ## Plan for entire simulation
#
# I think we'll want two output files from the simulation:
#
# - file with number of rejections, with the following columns:
#     - total N
#     - percent case
#     - study
#     - alpha level (FDR - so can go up to 0.25)
#     - total original rejected
#     - current total rejected
#
# - and another with the OTU-level results, with these columns:
#     - otu
#     - study
#     - total N
#     - percent case
#     - pval
#     - qval

# %%
ctrl = h
case = crc

## First, get the qvalues using the entire dataset
potu = compare_otus_teststat(
    df, ctrl, case, 
    method='kruskal-wallis', multi_comp='fdr')
pgenus = compare_otus_teststat(
    genusdf, ctrl, case, 
    method='kruskal-wallis', multi_comp='fdr')

# %%
print(sum(potu['q'] <= alpha), sum(pgenus['q'] <= alpha))
# Out:
# (7, 16)

# %%
## Set up simulation parameters
# Total N and % cases/controls needs to be limited by available N
maxN = len(case + ctrl)

# Total N is defined as a function of "reasonable" clinical trials
totalNs = [10, 25, 50, 75, 100, 150, 200]
perc_success = [0.1, 0.25, 0.5, 0.75, 0.9]

## Run simulation
for n in totalNs:
    for p in perc_success:
        # Define number of cases and controls
        n_ctrl = int(np.ceil((1.0 - p)*n))
        n_case = int(np.ceil(p*n))
        
        if (n_ctrl > len(ctrl)) or (n_case > len(case)):
            # Return np.nan here!
            print("Check your parameter settings, asking for too many samples!")
            continue
        
        print(n, p, n_ctrl, n_case)
        
        # Subsample our cases and controls
        subctrl = np.random.choice(ctrl, size=n_ctrl)
        subcase = np.random.choice(case, size=n_case)
        
        # Calculate qvalues, OTU-level
        #psub = compare_otus_teststat(
        #    df, subctrl, subcase, 
        #    method='kruskal-wallis', multi_comp='fdr')
        
        # Calculate qvalues, genus-level
        psubgenus = compare_otus_teststat(
            genusdf, subctrl, subcase, 
            method='kruskal-wallis', multi_comp='fdr')

        #print(sum(psub['q'] <= alpha), sum(psubgenus['q'] <= alpha))
        print(sum(psubgenus['q'] <= alpha))
# Out:
# (10, 0.1, 9, 1)
# 0
# (10, 0.25, 8, 3)
# 0
# (10, 0.5, 5, 5)
# 0
# (10, 0.75, 3, 8)
# 0
# (10, 0.9, 1, 9)
# 0
# (25, 0.1, 23, 3)
# 0
# (25, 0.25, 19, 7)
# 0
# (25, 0.5, 13, 13)
# 0
# (25, 0.75, 7, 19)
# 0
# (25, 0.9, 3, 23)
# 0
# (50, 0.1, 45, 5)
# 1
# (50, 0.25, 38, 13)
# 0
# (50, 0.5, 25, 25)
# 0
# (50, 0.75, 13, 38)
# 0
# (50, 0.9, 5, 45)
# 3
# (75, 0.1, 68, 8)
# 3
# (75, 0.25, 57, 19)
# 0
# (75, 0.5, 38, 38)
# 4
# (75, 0.75, 19, 57)
# 0
# (75, 0.9, 8, 68)
# 0
# (100, 0.1, 90, 10)
# 2
# (100, 0.25, 75, 25)
# 2
# (100, 0.5, 50, 50)
# 0
# (100, 0.75, 25, 75)
# 0
# (100, 0.9, 10, 90)
# 0
# (150, 0.1, 135, 15)
# 3
# (150, 0.25, 113, 38)
# 6
# (150, 0.5, 75, 75)
# 7
# (150, 0.75, 38, 113)
# 0
# Check your parameter settings, asking for too many samples!
# Check your parameter settings, asking for too many samples!
# (200, 0.25, 150, 50)
# 13
# (200, 0.5, 100, 100)
# 15
# Check your parameter settings, asking for too many samples!
# Check your parameter settings, asking for too many samples!

# %% [markdown]
# Ok, this works pretty well and I definitely really want to see all the results together. It's very strange to me the the 10% and 90% are sometimes doing better than the 50% split! Need to do a few reps of this...

# %% [markdown]
# ## Scratch work to write power_simulation.py

# %%
DATASETS = ['cdi_schubert', 'crc_baxter', 'ibd_papa', 'ob_goodrich']

for dataset in DATASETS:
    fotu = '../../data/clean/' + dataset + '.otu_table.feather'
    fgenus = '../../data/clean/' + dataset + '.otu_table.genus.feather'
    fmeta = '../../data/clean/' + dataset + '.metadata.feather'

    df, genusdf, meta = (read_dataframe(f) for f in [fotu, fgenus, fmeta])
    print(dataset)
    print(meta.groupby(['DiseaseState']).size())
    print("")
# Out:
# cdi_schubert
# DiseaseState
# CDI        93
# H         154
# nonCDI     89
# dtype: int64
#
# crc_baxter
# DiseaseState
# CRC       120
# H         172
# nonCRC    198
# dtype: int64
#
# ibd_papa
# DiseaseState
# CD          23
# IBDundef     1
# UC          43
# nonIBD      24
# dtype: int64
#
# ob_goodrich
# DiseaseState
# H     428
# OB    185
# OW    319
# dtype: int64

# %%
import copy

tmpdf = copy.deepcopy(pgenus)

# %%
tmpdf.columns
# Out:
# Index([u'p', u'test_stat', u'q'], dtype='object')

# %%
tmpdf = tmpdf.rename(columns={'p': 'p_allsamples',
                              'q': 'q_allsamples',
                              'test_stat': 'test_stat_allsamples'})

# %%
pd.concat((tmpdf, pgenus), axis=1)
# Out:
#                                                     p_allsamples  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.885686
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.394988
# k__Bacteria;p__Proteobacteria;c__Alphaproteobac...      0.152064
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.195144
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.252247
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.016093
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.003626
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.927988
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.715993
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.171321
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.072544
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.011067
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.258094
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.790127
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.713122
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.089880
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.650592
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.687764
# k__Bacteria;p__Synergistetes;c__Synergistia;o__...      0.029751
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.430411
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.006069
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.245043
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.191615
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.152018
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.119464
# k__Bacteria;p__Proteobacteria;c__Epsilonproteob...      0.024392
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.517065
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.004885
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.726210
# k__Bacteria;p__Proteobacteria;c__Deltaproteobac...      0.033158
# ...                                                          ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.739531
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.506253
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.246902
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.854417
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.506946
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.523023
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.071612
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.089631
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...      0.793856
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.757067
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.716618
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.236699
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.201139
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.066695
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.137320
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.578064
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.313171
# k__Bacteria;p__Cyanobacteria/Chloroplast;c__Chl...      0.202620
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.817258
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.699330
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.100290
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.351106
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.662044
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.045223
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.000012
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.681862
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.036710
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.611372
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.362999
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.420582
#
#                                                     test_stat_allsamples  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              0.020668
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...              0.723531
# k__Bacteria;p__Proteobacteria;c__Alphaproteobac...              2.051424
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              1.678349
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...              1.310813
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              5.792711
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              8.462056
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.008168
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              0.132365
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              1.871345
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              3.224493
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              6.454487
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              1.278950
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              0.070833
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              0.135179
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...              2.876518
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.205155
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...              0.161517
# k__Bacteria;p__Synergistetes;c__Synergistia;o__...              4.723609
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.621714
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              7.529772
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...              1.351344
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              1.705153
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              2.051881
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...              2.424329
# k__Bacteria;p__Proteobacteria;c__Epsilonproteob...              5.066532
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...              0.419744
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              7.921526
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...              0.122620
# k__Bacteria;p__Proteobacteria;c__Deltaproteobac...              4.537595
# ...                                                                  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              0.110540
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.441803
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              1.340749
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.033667
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              0.440366
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              0.407929
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              3.245690
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              2.880995
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...              0.068281
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...              0.095688
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.131756
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              1.400144
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...              1.634087
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              3.362540
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              2.207742
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              0.309375
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              1.017255
# k__Bacteria;p__Cyanobacteria/Chloroplast;c__Chl...              1.623388
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...              0.053395
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.149170
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              2.700926
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...              0.869454
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              0.191050
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...              4.010302
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...             19.168040
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.168038
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              4.363827
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...              0.258182
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...              0.827490
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...              0.648688
#
#                                                     q_allsamples         p  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.907967  0.885686
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.674756  0.394988
# k__Bacteria;p__Proteobacteria;c__Alphaproteobac...      0.467668  0.152064
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.532524  0.195144
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.532524  0.252247
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.114049  0.016093
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.046417  0.003626
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.939516  0.927988
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.830594  0.715993
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.503981  0.171321
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.303198  0.072544
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.081998  0.011067
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.532524  0.258094
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.856944  0.790127
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.830594  0.713122
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.340709  0.089880
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.829982  0.650592
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.830594  0.687764
# k__Bacteria;p__Synergistetes;c__Synergistia;o__...      0.182230  0.029751
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.701570  0.430411
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.054258  0.006069
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.532524  0.245043
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.532524  0.191615
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.467668  0.152018
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...      0.408166  0.119464
# k__Bacteria;p__Proteobacteria;c__Epsilonproteob...      0.165663  0.024392
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.781066  0.517065
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.049766  0.004885
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.830594  0.726210
# k__Bacteria;p__Proteobacteria;c__Deltaproteobac...      0.193028  0.033158
# ...                                                          ...       ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.837107  0.739531
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.779549  0.506253
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.532524  0.246902
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.887070  0.854417
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.779549  0.506946
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...      0.782135  0.523023
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.303198  0.071612
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.340709  0.089631
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...      0.856944  0.793856
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.839468  0.757067
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...      0.830594  0.716618
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.532524  0.236699
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.532524  0.201139
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.293819  0.066695
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.456798  0.137320
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.827769  0.578064
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.630208  0.313171
# k__Bacteria;p__Cyanobacteria/Chloroplast;c__Chl...      0.532524  0.202620
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.865020  0.817258
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.830594  0.699330
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.363273  0.100290
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.662212  0.351106
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.830101  0.662044
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...      0.230355  0.045223
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.000390  0.000012
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.830594  0.681862
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.203503  0.036710
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...      0.827769  0.611372
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...      0.666545  0.362999
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      0.692474  0.420582
#
#                                                     test_stat         q
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...   0.020668  0.907967
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...   0.723531  0.674756
# k__Bacteria;p__Proteobacteria;c__Alphaproteobac...   2.051424  0.467668
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...   1.678349  0.532524
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   1.310813  0.532524
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   5.792711  0.114049
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   8.462056  0.046417
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.008168  0.939516
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   0.132365  0.830594
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   1.871345  0.503981
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   3.224493  0.303198
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   6.454487  0.081998
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...   1.278950  0.532524
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   0.070833  0.856944
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   0.135179  0.830594
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   2.876518  0.340709
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.205155  0.829982
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...   0.161517  0.830594
# k__Bacteria;p__Synergistetes;c__Synergistia;o__...   4.723609  0.182230
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.621714  0.701570
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   7.529772  0.054258
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...   1.351344  0.532524
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   1.705153  0.532524
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   2.051881  0.467668
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...   2.424329  0.408166
# k__Bacteria;p__Proteobacteria;c__Epsilonproteob...   5.066532  0.165663
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   0.419744  0.781066
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   7.921526  0.049766
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   0.122620  0.830594
# k__Bacteria;p__Proteobacteria;c__Deltaproteobac...   4.537595  0.193028
# ...                                                       ...       ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   0.110540  0.837107
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.441803  0.779549
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   1.340749  0.532524
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.033667  0.887070
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...   0.440366  0.779549
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...   0.407929  0.782135
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...   3.245690  0.303198
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   2.880995  0.340709
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...   0.068281  0.856944
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...   0.095688  0.839468
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...   0.131756  0.830594
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...   1.400144  0.532524
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...   1.634087  0.532524
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...   3.362540  0.293819
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   2.207742  0.456798
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   0.309375  0.827769
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   1.017255  0.630208
# k__Bacteria;p__Cyanobacteria/Chloroplast;c__Chl...   1.623388  0.532524
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...   0.053395  0.865020
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.149170  0.830594
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   2.700926  0.363273
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...   0.869454  0.662212
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   0.191050  0.830101
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   4.010302  0.230355
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  19.168040  0.000390
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.168038  0.830594
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   4.363827  0.203503
# k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o...   0.258182  0.827769
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...   0.827490  0.666545
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...   0.648688  0.692474
#
# [163 rows x 6 columns]
